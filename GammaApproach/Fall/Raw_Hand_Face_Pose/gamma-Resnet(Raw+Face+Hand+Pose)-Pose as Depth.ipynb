# %%
import numpy as np
#%matplotlib inline
#import matplotlib.pyplot as plt
from PIL import Image  , ImageDraw 
import torch
from torchvision import datasets, models, transforms
import torch.nn as nn
from torch.nn import functional as F
import torch.optim as optim
import os
import json

# %%
torch.__version__
# Out:
# '1.5.0+cu101'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# %cd drive/My Drive/Resnet_Beta-Version
# !ls
# Out:
# /content/drive/My Drive/Resnet_Beta-Version
#  acc
# 'alpha-Resnet(Raw+Face+Hand).ipynb'
# 'alpha-Resnet(Raw+Face).ipynb'
# 'alpha-Resnet(Raw+Hand).ipynb'
# 'alpha-Resnet(Raw).ipynb'
# 'Arrange Dataset.ipynb'
# 'beta-Resnet(Raw+Face+Hand).ipynb'
# 'beta-Resnet(Raw+Face+Hand+Pose)-Pose as Depth.ipynb'
# 'beta-Resnet(Raw+Face).ipynb'
# 'beta-Resnet(Raw+Hand).ipynb'
# 'beta-Resnet(Raw).ipynb'
#  dataset
#  dump
#  epoch_65.pth
#  extract_faceandhand_jorehgaye.ipynb
#  fallingDemo.ipynb
#  fallingDemo_modified_2.py
#  fallingDemo_modified.py
#  fallingDemo.py
# 'gamma-Resnet(Raw+Face+Hand).ipynb'
# 'gamma-Resnet(Raw+Face+Hand+Pose)-Pose as Depth.ipynb'
# 'gamma-Resnet(Raw+Face).ipynb'
# 'gamma-Resnet(Raw+Hand).ipynb'
# 'gamma-Resnet(Raw).ipynb'
#  loss
#  out.jpg
#  putTXT_rightplace.ipynb
# 'Testbeta-Resnet(Raw+Face+Hand).ipynb'
# 'Testbeta-Resnet(Raw+Face+Hand+Pose)-Pose as Depth.ipynb'
# 'Testbeta-Resnet(Raw+Face).ipynb'
# 'Testbeta-Resnet(Raw+Hand).ipynb'
# 'Testbeta-Resnet(Raw).ipynb'
#  TestingModels_first_gamma.ipynb
#  TestingModels_first.ipynb
#  TestingModels_gamma.ipynb
#  TestingModels_second.ipynb
#  TestingModels_the-third.ipynb
#  weights

# %%
normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                 std=[0.229, 0.224, 0.225])

data_transforms = {
    'train':
    transforms.Compose([
        transforms.Resize((224,224)),
        transforms.ToTensor(),
        #normalize
    ]),
    'validation':
    transforms.Compose([
        transforms.Resize((224,224)),
        transforms.ToTensor(),
        #normalize
    ]),
}

# %%
class MyImageFolder(datasets.ImageFolder):
    
    def __init__(self, root, transform=None):
        super(MyImageFolder,self).__init__(root)

        self.transform = transform

    def __getitem__(self, index):

        #imgs = self.imgs[index]
        #print(imgs)

        path, target = self.samples[index]
        #sample = self.loader(path)
        #print("Sample: ",sample)
        

        hm_transform = transforms.Compose([
                          transforms.Resize((224,224)),
                          transforms.ToTensor()

                                ])
        self.transform = hm_transform
        #print(path)
        #print(type(path))
        #all_images = []
        #all_labels = []
        #all_hm_face = []
        #all_hm_hand = []
        # target_acquired - 0: image path -- 1: label
        #for i in len(path):

        img_path = path
        #print("--i: %d , TA: %s"%(i,target_acquired))

        
        #img_path = target_acquired
        #label =  target_acquired[1]

        #print(img_path)

        image = Image.open(img_path)
        img_w , img_h = image.size

    
        filename = os.path.basename(img_path)
        ann_path = img_path.replace(filename, filename.split('.')[0])
        hm_face , hm_hand = self.get_heatmap(ann_path + '.txt',img_w,img_h)  
        hm_pose = self.get_heatmap_pose(ann_path + '.json',img_w,img_h)
        #image = np.dstack((image, hm_face))
        cpath  = img_path.replace(filename, filename.split('.')[0] + '-bbox.txt')
         
        image,hm_face,hm_hand,hm_pose = self.crop_text(cpath,image,hm_face,hm_hand,hm_pose)
        # Transforms
        if self.transform is not None:
            
            image = self.transform(image)
            hm_face = hm_transform(hm_face)
            hm_hand = hm_transform(hm_hand)
            hm_pose = torch.stack([ hm_transform(x) for x in hm_pose ], dim=1).squeeze(0)


        #print( hm_pose.size() )
        image = torch.cat((image,hm_face,hm_hand,hm_pose))
       
        #print(image.size())
        #if self.target_transform is not None:
        #    target = self.target_transform(target)
        
        
        # For Face
            #image = np.dstack((image, hm_face))

            #all_images.append(img_path)
            #all_labels.append(label)
            #all_hm_face.append(hm_face)
            #all_hm_hand.append(hm_hand)

        #return path, all_hm_face, all_hm_hand, target
        
        return image, target

    def crop_text(self,path,image,hm_face,hm_hand,hm_pose):
        try:
              fr = open(path)
              # print ("fr",cat+"/yolo/" + imagePath.split("/")[-1].split('.')[0]+".txt")

              line = fr.readline().split(" ")

              width, height = image.size 
        
              # Setting the points ffloor cropped image
              b_w = float(line[3]) * width
              b_h = float(line[4]) * height

              t_left = (float(line[1]) * width) - (b_w/2)
              t_right = (float(line[2]) * height) - (b_h/2)

              b_left = (float(line[1]) * width) + (b_w/2)
              b_right = (float(line[2]) * height) + (b_h/2)

              # print("w",width," h",height)

              # print (t_left)
              # print (t_right)
              # print (b_left)
              # print (b_right)

              image = image.crop((t_left, t_right, b_left, b_right))
              
              hm_face = hm_face.crop((t_left, t_right, b_left, b_right))
              hm_hand = hm_hand.crop((t_left, t_right, b_left, b_right))
              
              for i in range(len(hm_pose)):
                  hm_pose[i] = hm_pose[i].crop((t_left, t_right, b_left, b_right))

        except FileNotFoundError:
              print("FileNotFoundError: " + path)
              #pass
        return image ,hm_face,hm_hand,hm_pose

    def get_heatmap(self,ann_path, img_w , img_h):
        
        hm_0 = Image.new('L', (img_w, img_h))
        hm_1 = Image.new('L', (img_w, img_h))
        
        try:

            with open(ann_path) as f:

                for line in f.readlines():

                    if line == '\n':
                        continue

                    line = line.split(' ')

                    cx = float(line[1])
                    cy = float(line[2])
                    w = float(line[3])
                    h = float(line[4])

                    xmin =  (cx - (w/2)) * img_w
                    ymin = (cy - (h/2)) * img_h
                    xmax = (cx + (w/2)) * img_w
                    ymax = (cy + (h/2)) * img_h

                    if line[0] == '0':
                        hmDraw = ImageDraw.Draw(hm_0)   
                    else:
                        hmDraw = ImageDraw.Draw(hm_1)   
                    
                    hmDraw.rectangle([xmin,ymin,xmax,ymax], fill ="#ffffff")
        except FileNotFoundError:
            #print("FileNotFoundError: %s"%ann_path)
            pass

        return hm_0, hm_1

    def get_heatmap_pose(self,ann_path, img_w, img_h):
        
        heatmaps = [ Image.new('L', (img_w, img_h)) for x in range(17) ]

        try:
            with open(ann_path,'r') as f:
                data = json.load(f)
            #print(ann_path)
            #print(data)  
            try:
                keypoints = data[0]['keypoints']
            except IndexError:
                return heatmaps

            #print(keypoints)
            # TODO check for two key mappings -- working

            for i in range(0,len(keypoints),3):

                xmin = keypoints[i] - 5
                ymin = keypoints[i+1] - 5
                xmax = keypoints[i] + 5
                ymax = keypoints[i+1] + 5

                hmDraw = ImageDraw.Draw(heatmaps[i//3]) 
                hmDraw.rectangle([xmin,ymin,xmax,ymax], fill ="#ffffff")

        except FileNotFoundError:
            #print("FileNotFoundError: %s"%ann_path)
            pass

        return heatmaps



"""
Test Code


path, target = self.samples[index]
sample = self.loader(path)
if self.transform is not None:
  sample = self.transform(sample)
if self.target_transform is not None:
  target = self.target_transform(target)
# this is where you load your resnet data
resnet_path = os.path.join(os.path.splitext(path)[0], '.pth')  # replace image extension with .pth
resnet = torch.load(resnet_path)  # load the stored features
return sample, resnet, target

#dataset = MyImageFolder("falling_dataset/val/")
#dataset[0]
#h = dataset.get_heatmap_pose("falling_dataset/train/Falling/11107.json",1280,720)
#print(len(h))
#for i in range(len(h)):
#    h[i].save("Annotated/train/%d.jpg"%(i))

path = "./falling_dataset/train/Falling"
# !pwd
for file in os.listdir(path):
    if file.endswith(".json"):
        #print(os.path.join(path, file))

        with open(os.path.join(path, file)) as f:
            string = f.readline()
            if string == '[]':
                print(os.path.join(path, file))



#re, labels = dataset[1:3]
#print(re)
#print(labels)
#re[2].save('pred_face.jpeg')
#re[3].save('pred_hand.jpeg')
"""
# Out:
# '\nTest Code\n\n\npath, target = self.samples[index]\nsample = self.loader(path)\nif self.transform is not None:\n  sample = self.transform(sample)\nif self.target_transform is not None:\n  target = self.target_transform(target)\n# this is where you load your resnet data\nresnet_path = os.path.join(os.path.splitext(path)[0], \'.pth\')  # replace image extension with .pth\nresnet = torch.load(resnet_path)  # load the stored features\nreturn sample, resnet, target\n\n#dataset = MyImageFolder("falling_dataset/val/")\n#dataset[0]\n#h = dataset.get_heatmap_pose("falling_dataset/train/Falling/11107.json",1280,720)\n#print(len(h))\n#for i in range(len(h)):\n#    h[i].save("Annotated/train/%d.jpg"%(i))\n\npath = "./falling_dataset/train/Falling"\n!pwd\nfor file in os.listdir(path):\n    if file.endswith(".json"):\n        #print(os.path.join(path, file))\n\n        with open(os.path.join(path, file)) as f:\n            string = f.readline()\n            if string == \'[]\':\n                print(os.path.join(path, file))\n\n\n\n#re, labels = dataset[1:3]\n#print(re)\n#print(labels)\n#re[2].save(\'pred_face.jpeg\')\n#re[3].save(\'pred_hand.jpeg\')\n'

# %%
input_path = './dataset/alpha/Fall'

image_datasets = {
    'train': 
    MyImageFolder(input_path + '/train', data_transforms['train']),
    'validation': 
    MyImageFolder(input_path + '/val', data_transforms['validation'])
}

dataloaders = {
    'train':
    torch.utils.data.DataLoader(image_datasets['train'],
                                batch_size=64,
                                shuffle=True,
                                num_workers=2),  # for Kaggle
    'validation':
    torch.utils.data.DataLoader(image_datasets['validation'],
                                batch_size=32,
                                shuffle=False,
                                num_workers=2)  # for Kaggle
}

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda', index=0)

# %%
model = models.resnet50(pretrained=True).to(device)

model.cuda()
#print(model)

depth = 22    # ( 3 + 1 + 1 + 17 )


for param in model.parameters():
    param.requires_grad = False   


#------------ Modify First Layer
model.conv1 = nn.Conv2d(depth, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False).to(device)
model.conv1.requires_grad = True

#------------ Modify Last Layer
model.fc = nn.Sequential(
               nn.Linear(2048, 128),
               nn.ReLU(inplace=True),
               nn.Linear(128, 2),
               nn.Sigmoid()).to(device)
#epoch = 87
#model = (torch.load('weights/gamma/Fall/raw-face-hand-pose/epoch_%d.pth'%epoch))

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.fc.parameters(),lr=0.001)

# %%
def train_model(model, criterion, optimizer, num_epochs=3):
    new_write = True
    for epoch in range(num_epochs):
        
        f = open('loss/gamma/Choke/raw-face-hand-pose.txt','a+')
        
        print('Epoch {}/{}'.format(epoch+1, num_epochs))
        print('-' * 10)
        f.write('Epoch {}/{}\n'.format(epoch+1, num_epochs))
        

        for phase in ['train','validation']:
            if phase == 'train':
                model.train()
            else:
                model.eval()

            running_loss = 0.0
            running_corrects = 0
            count = 0
            
            with torch.set_grad_enabled(phase == 'train'):
                for inputs, labels in dataloaders[phase]:
                    inputs = inputs.to(device)
                    labels = labels.to(device)

                    outputs = model(inputs)
                    loss = criterion(outputs, labels)

                    if phase == 'train':

                        optimizer.zero_grad()
                        loss.backward()
                        optimizer.step()

                    _, preds = torch.max(outputs, 1)
                    running_loss += loss.item() * inputs.size(0)
                    running_corrects += torch.sum(preds == labels.data)

                    count = count+1                
                    if (count%40==0):
                        print (count)
             

            epoch_loss = running_loss / len(image_datasets[phase])
            epoch_acc = running_corrects.double() / len(image_datasets[phase])

            print('{} loss: {:.4f}, acc: {:.4f}'.format(phase,epoch_loss,epoch_acc))
            if (os.path.isfile('loss/gamma/Choke/raw_face_hand_pose.txt')):
              new_write=False  
            else :
              print ("No file")
            f = open('loss/gamma/Choke/raw_face_hand_pose.txt','a+')
            if  (new_write == True ):
              print ("here")
              f.write('{} loss: {:.4f}, acc: {:.4f}'.format(phase,epoch_loss,epoch_acc))
            else :
              f.write ('\n')
              f.write('{} loss: {:.4f}, acc: {:.4f}'.format(phase,epoch_loss,epoch_acc))
            
            
        torch.save(model, '/content/drive/My Drive/Fyp/gamma/Choke/raw-face-hand-pose/epoch_%d.pth'%(epoch))
        f.close()


    return model

# %%
train_model(model, criterion, optimizer, num_epochs=100)
# Out:
# Epoch 1/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# train loss: 0.6419, acc: 0.6410
# No file
# here
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.6493, acc: 0.5857
# Epoch 2/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# train loss: 0.5821, acc: 0.7200
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.5628, acc: 0.7527
# Epoch 3/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# 40
# train loss: 0.5667, acc: 0.7332
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.5480, acc: 0.7554
# Epoch 4/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# train loss: 0.5539, acc: 0.7499
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.5385, acc: 0.7726
# Epoch 5/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# train loss: 0.5375, acc: 0.7636
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.5326, acc: 0.7780
# Epoch 6/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# train loss: 0.5261, acc: 0.7773
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.5338, acc: 0.7699
# Epoch 7/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# train loss: 0.5258, acc: 0.7814
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.5276, acc: 0.7780
# Epoch 8/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# train loss: 0.5451, acc: 0.7546
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.5443, acc: 0.7536
# Epoch 9/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# train loss: 0.5153, acc: 0.7905
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.5197, acc: 0.7798
# Epoch 10/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# train loss: 0.5100, acc: 0.7923
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.5213, acc: 0.7843
# Epoch 11/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# train loss: 0.5099, acc: 0.7930
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.5466, acc: 0.7446
# Epoch 12/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# train loss: 0.5082, acc: 0.7982
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.5166, acc: 0.7852
# Epoch 13/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# train loss: 0.5008, acc: 0.8052
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.5114, acc: 0.7933
# Epoch 14/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# 40
# train loss: 0.5023, acc: 0.8023
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.5371, acc: 0.7635
# Epoch 15/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# train loss: 0.5030, acc: 0.7979
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.5103, acc: 0.7951
# Epoch 16/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# train loss: 0.4929, acc: 0.8160
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.5044, acc: 0.7942
# Epoch 17/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# train loss: 0.4883, acc: 0.8204
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.5037, acc: 0.8023
# Epoch 18/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# train loss: 0.4936, acc: 0.8152
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.5249, acc: 0.7744
# Epoch 19/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# train loss: 0.4893, acc: 0.8183
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.5023, acc: 0.8032
# Epoch 20/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# train loss: 0.5024, acc: 0.8026
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.5094, acc: 0.7915
# Epoch 21/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# train loss: 0.4892, acc: 0.8147
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.5060, acc: 0.7897
# Epoch 22/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# train loss: 0.4835, acc: 0.8232
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.4968, acc: 0.8051
# Epoch 23/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# train loss: 0.4736, acc: 0.8377
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.5108, acc: 0.7897
# Epoch 24/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# train loss: 0.4952, acc: 0.8098
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.4980, acc: 0.8060
# Epoch 25/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# train loss: 0.5041, acc: 0.7982
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.5024, acc: 0.8023
# Epoch 26/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# train loss: 0.4757, acc: 0.8333
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.4943, acc: 0.8114
# Epoch 27/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# train loss: 0.4877, acc: 0.8163
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.4985, acc: 0.8032
# Epoch 28/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# train loss: 0.4738, acc: 0.8317
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.4941, acc: 0.8114
# Epoch 29/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# train loss: 0.4950, acc: 0.8057
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.4957, acc: 0.8114
# Epoch 30/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# 40
# train loss: 0.4674, acc: 0.8410
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.5010, acc: 0.8005
# Epoch 31/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# train loss: 0.4697, acc: 0.8335
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.4958, acc: 0.8005
# Epoch 32/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# train loss: 0.4580, acc: 0.8565
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.4885, acc: 0.8168
# Epoch 33/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# train loss: 0.4580, acc: 0.8524
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.5090, acc: 0.7933
# Epoch 34/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# train loss: 0.4552, acc: 0.8539
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.4860, acc: 0.8213
# Epoch 35/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# train loss: 0.4565, acc: 0.8565
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.4826, acc: 0.8204
# Epoch 36/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# train loss: 0.4537, acc: 0.8565
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.4946, acc: 0.8105
# Epoch 37/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# 40
# train loss: 0.4542, acc: 0.8516
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.4873, acc: 0.8186
# Epoch 38/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# train loss: 0.4415, acc: 0.8692
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.4847, acc: 0.8204
# Epoch 39/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# train loss: 0.4567, acc: 0.8511
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.4912, acc: 0.8204
# Epoch 40/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# train loss: 0.4453, acc: 0.8622
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.5059, acc: 0.7915
# Epoch 41/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# 40
# train loss: 0.4523, acc: 0.8550
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.4831, acc: 0.8213
# Epoch 42/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# train loss: 0.4545, acc: 0.8529
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.5008, acc: 0.8023
# Epoch 43/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# train loss: 0.4558, acc: 0.8539
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.5320, acc: 0.7726
# Epoch 44/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# train loss: 0.4525, acc: 0.8526
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.4907, acc: 0.8150
# Epoch 45/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# train loss: 0.4401, acc: 0.8699
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.4768, acc: 0.8285
# Epoch 46/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# train loss: 0.4434, acc: 0.8705
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.4741, acc: 0.8357
# Epoch 47/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# train loss: 0.4343, acc: 0.8790
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.4969, acc: 0.8014
# Epoch 48/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# train loss: 0.4386, acc: 0.8715
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.4767, acc: 0.8303
# Epoch 49/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# train loss: 0.4405, acc: 0.8702
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.4793, acc: 0.8267
# Epoch 50/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# train loss: 0.4269, acc: 0.8857
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.4705, acc: 0.8303
# Epoch 51/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# train loss: 0.4276, acc: 0.8831
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.4763, acc: 0.8240
# Epoch 52/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# train loss: 0.4263, acc: 0.8854
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.4713, acc: 0.8366
# Epoch 53/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# train loss: 0.4365, acc: 0.8735
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.5182, acc: 0.7762
# Epoch 54/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# train loss: 0.4318, acc: 0.8805
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.4955, acc: 0.8105
# Epoch 55/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# train loss: 0.4281, acc: 0.8805
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.5178, acc: 0.7825
# Epoch 56/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# train loss: 0.4171, acc: 0.8952
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.4839, acc: 0.8231
# Epoch 57/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# train loss: 0.4165, acc: 0.8965
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.4647, acc: 0.8421
# Epoch 58/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# train loss: 0.4218, acc: 0.8898
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.4642, acc: 0.8448
# Epoch 59/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# train loss: 0.4083, acc: 0.9079
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.4785, acc: 0.8258
# Epoch 60/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# train loss: 0.4095, acc: 0.9043
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.4549, acc: 0.8484
# Epoch 61/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# train loss: 0.4140, acc: 0.8994
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.5018, acc: 0.8014
# Epoch 62/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# train loss: 0.4158, acc: 0.8970
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.4681, acc: 0.8294
# Epoch 63/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# train loss: 0.4093, acc: 0.9030
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.4555, acc: 0.8529
# Epoch 64/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# train loss: 0.3985, acc: 0.9185
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.4534, acc: 0.8493
# Epoch 65/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# train loss: 0.4071, acc: 0.9074
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.4594, acc: 0.8448
# Epoch 66/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# train loss: 0.4036, acc: 0.9110
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.4539, acc: 0.8565
# Epoch 67/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# train loss: 0.4072, acc: 0.9079
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.4507, acc: 0.8574
# Epoch 68/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# train loss: 0.4003, acc: 0.9174
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.4466, acc: 0.8646
# Epoch 69/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# train loss: 0.4025, acc: 0.9141
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.4504, acc: 0.8574
# Epoch 70/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# train loss: 0.4152, acc: 0.8960
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.4470, acc: 0.8610
# Epoch 71/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# train loss: 0.3986, acc: 0.9141
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.4532, acc: 0.8520
# Epoch 72/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# train loss: 0.3969, acc: 0.9200
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.4723, acc: 0.8294
# Epoch 73/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# train loss: 0.3957, acc: 0.9185
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.4470, acc: 0.8565
# Epoch 74/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# train loss: 0.3973, acc: 0.9172
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.4766, acc: 0.8321
# Epoch 75/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# train loss: 0.3863, acc: 0.9314
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.4399, acc: 0.8709
# Epoch 76/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# train loss: 0.3828, acc: 0.9350
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.4428, acc: 0.8592
# Epoch 77/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# train loss: 0.3839, acc: 0.9329
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.4675, acc: 0.8403
# Epoch 78/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# train loss: 0.3936, acc: 0.9218
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.4365, acc: 0.8736
# Epoch 79/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# train loss: 0.3885, acc: 0.9290
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.4402, acc: 0.8664
# Epoch 80/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# train loss: 0.3737, acc: 0.9440
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.4345, acc: 0.8727
# Epoch 81/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
