# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
from PIL import Image
import torch
from torchvision import datasets, models, transforms
import torch.nn as nn
from torch.nn import functional as F
import torch.optim as optim
import os

# %%
torch.__version__
# Out:
# '1.5.0+cu101'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !ls
# Out:
# drive  sample_data

# %%
#with open('/gdrive/My Drive/foo.txt', 'w') as f:
 # f.write('Hello Google Drive!')
#!cat '/gdrive/My Drive/foo.txt'

# %%
#%cd drive/My Drive/AlphaPose/AlphaPose-pytorch
#input_path = "/content/drive/My Drive/AlphaPose/AlphaPose-pytorch/fi_data"

# %%
#!python3 datalabeler_111.py

# %%
# %cd drive/My Drive/Resnet_Beta-Version
# !ls
# Out:
# /content/drive/My Drive/Resnet_Beta-Version
#  acc
# 'alpha-Resnet(Raw+Face+Hand).ipynb'
# 'alpha-Resnet(Raw+Face).ipynb'
# 'alpha-Resnet(Raw+Hand).ipynb'
# 'alpha-Resnet(Raw).ipynb'
# 'Arrange Dataset.ipynb'
# 'beta-Resnet(Raw+Face+Hand).ipynb'
# 'beta-Resnet(Raw+Face+Hand+Pose)-Pose as Depth.ipynb'
# 'beta-Resnet(Raw+Face).ipynb'
# 'beta-Resnet(Raw+Hand).ipynb'
# 'beta-Resnet(Raw).ipynb'
#  dataset
#  dump
#  epoch_65.pth
#  extract_faceandhand_jorehgaye.ipynb
#  fallingDemo.ipynb
#  fallingDemo_modified_2.py
#  fallingDemo_modified.py
#  fallingDemo.py
# 'gamma-Resnet(Raw+Face+Hand).ipynb'
# 'gamma-Resnet(Raw+Face+Hand+Pose)-Pose as Depth.ipynb'
# 'gamma-Resnet(Raw+Face).ipynb'
# 'gamma-Resnet(Raw+Hand).ipynb'
# 'gamma-Resnet(Raw).ipynb'
#  loss
#  out.jpg
#  putTXT_rightplace.ipynb
# 'Testbeta-Resnet(Raw+Face+Hand).ipynb'
# 'Testbeta-Resnet(Raw+Face+Hand+Pose)-Pose as Depth.ipynb'
# 'Testbeta-Resnet(Raw+Face).ipynb'
# 'Testbeta-Resnet(Raw+Hand).ipynb'
# 'Testbeta-Resnet(Raw).ipynb'
#  TestingModels_first.ipynb
#  TestingModels_second.ipynb
#  TestingModels_the-third.ipynb
#  weights

# %%
normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                 std=[0.229, 0.224, 0.225])

data_transforms = {
    'train':
    transforms.Compose([
        transforms.Resize((224,224)),
        #transforms.RandomAffine(0, shear=10, scale=(0.8,1.2)),
        #transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        normalize
    ]),
    'validation':
    transforms.Compose([
        transforms.Resize((224,224)),
        transforms.ToTensor(),
        normalize
    ]),
}

# %%
class MyImageFolder(datasets.ImageFolder):
    
    def __init__(self, root, transform=None):
        super(MyImageFolder,self).__init__(root)

        self.transform = transform
        




    def __getitem__(self, index):

        #imgs = self.imgs[index]
        #print(imgs)

        path, target = self.samples[index]
        #sample = self.loader(path)
        #print("Sample: ",sample)
        

       
        img_path = path
       
        image = Image.open(img_path)
        img_w , img_h = image.size

    
        filename = os.path.basename(img_path)
       
        #Croping images to feeed 
        #if (os.path.isfile(filename.split('.')[0] + '-bbox.txt')):
        cpath  = img_path.replace(filename, filename.split('.')[0] + '-bbox.txt')
        image  = self.crop_text(cpath,image)
        #else:
        #  print("No file "+ filename)
    

        
        # Transforms
        if self.transform is not None:
            
            image = self.transform(image)
        
        return image, target


    def crop_text(self,path,image):
        try:
              fr = open(path)
              # print ("fr",cat+"/yolo/" + imagePath.split("/")[-1].split('.')[0]+".txt")

              line = fr.readline().split(" ")

              width, height = image.size 
        
              # Setting the points ffloor cropped image
              b_w = float(line[3]) * width
              b_h = float(line[4]) * height

              t_left = (float(line[1]) * width) - (b_w/2)
              t_right = (float(line[2]) * height) - (b_h/2)

              b_left = (float(line[1]) * width) + (b_w/2)
              b_right = (float(line[2]) * height) + (b_h/2)

              # print("w",width," h",height)

              # print (t_left)
              # print (t_right)
              # print (b_left)
              # print (b_right)

              image = image.crop((t_left, t_right, b_left, b_right))
              
        except FileNotFoundError:
              print("FileNotFoundError: " + path)
              #pass
        return image 
   
"""
Test Code


path, target = self.samples[index]
sample = self.loader(path)
if self.transform is not None:
  sample = self.transform(sample)
if self.target_transform is not None:
  target = self.target_transform(target)
# this is where you load your resnet data
resnet_path = os.path.join(os.path.splitext(path)[0], '.pth')  # replace image extension with .pth
resnet = torch.load(resnet_path)  # load the stored features
return sample, resnet, target
"""
#dataset = MyImageFolder("falling_dataset/val/")
#re, labels = dataset[1:3]
#print(re)
#print(labels)
#re[2].save('pred_face.jpeg')
#re[3].save('pred_hand.jpeg')
# Out:
# "\nTest Code\n\n\npath, target = self.samples[index]\nsample = self.loader(path)\nif self.transform is not None:\n  sample = self.transform(sample)\nif self.target_transform is not None:\n  target = self.target_transform(target)\n# this is where you load your resnet data\nresnet_path = os.path.join(os.path.splitext(path)[0], '.pth')  # replace image extension with .pth\nresnet = torch.load(resnet_path)  # load the stored features\nreturn sample, resnet, target\n"

# %%
#%cd

# %%
input_path = './dataset/alpha/Choke/'

image_datasets = {
    'train': 
    MyImageFolder(input_path+"train" , data_transforms['train']),
    'validation': 
    MyImageFolder(input_path+"val" , data_transforms['validation'])
}

#print(image_datasets['train'][0])

dataloaders = {
    'train':
    torch.utils.data.DataLoader(image_datasets['train'],
                                batch_size=64,
                                shuffle=True,
                                num_workers=8),  # for Kaggle
    'validation':
    torch.utils.data.DataLoader(image_datasets['validation'],
                                batch_size=32,
                                shuffle=False,
                                num_workers=8)  # for Kaggle
}

# %%
#image_datasets['train']=LimitDataset(image_datasets['train'], n=1500)
dataloaders['train'].dataset.classes
# Out:
# ['Choking', 'NonChoking']

# %%
dataloaders['validation'].dataset.classes
# Out:
# ['Choking', 'NonChoking']

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda', index=0)

# %%
model = models.resnet50(pretrained=True).to(device)
    
for param in model.parameters():
    param.requires_grad = False   
    
model.fc = nn.Sequential(
               nn.Linear(2048, 128),
               nn.ReLU(inplace=True),
               nn.Linear(128, 2),
               nn.Sigmoid()).to(device)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /root/.cache/torch/checkpoints/resnet50-19c8e357.pth
# HBox(children=(FloatProgress(value=0.0, max=102502400.0), HTML(value='')))

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.fc.parameters(),lr=0.001)

# %%
def train_model(model, criterion, optimizer, num_epochs=3):
    new_write = True
    for epoch in range(num_epochs):
        
        print('Epoch {}/{}'.format(epoch+1, num_epochs))
        print('-' * 10)
        
        #f.write('Epoch {}/{}'.format(epoch+1, num_epochs))
        

        for phase in ['train','validation']:
            if phase == 'train':
                model.train()
            else:
                model.eval()

            running_loss = 0.0
            running_corrects = 0
            count = 0
            
            with torch.set_grad_enabled(phase == 'train'):
              for inputs, labels in dataloaders[phase]:
                  inputs = inputs.to(device)
                  labels = labels.to(device)

                  outputs = model(inputs)
                  loss = criterion(outputs, labels)

                  if phase == 'train':
                      
                      optimizer.zero_grad()
                      loss.backward()
                      optimizer.step()

                  _, preds = torch.max(outputs, 1)
                  running_loss += loss.item() * inputs.size(0)
                  running_corrects += torch.sum(preds == labels.data)

                  count = count+1                
                  if (count%40==0):
                    print (count)
             

            epoch_loss = running_loss / len(image_datasets[phase])
            epoch_acc = running_corrects.double() / len(image_datasets[phase])

            print('{} loss: {:.4f}, acc: {:.4f}'.format(phase,epoch_loss,epoch_acc))
            if (os.path.isfile('loss/gamma/Choke/raw.txt')):
              new_write=False  
            else :
              print ("No file")
            f = open('loss/gamma/Choke/raw.txt','a+')
            if  (new_write == True ):
              print ("here")
              f.write('{} loss: {:.4f}, acc: {:.4f}'.format(phase,epoch_loss,epoch_acc))
            else :
              f.write ('\n')
              f.write('{} loss: {:.4f}, acc: {:.4f}'.format(phase,epoch_loss,epoch_acc))
            
            
        torch.save(model, '/content/drive/My Drive/Fyp/gamma/Choke/raw/epoch_%d.pth'%(epoch))
        f.close()


    return model

# %%
#count = 1
#torch.save(model, 'weights/pytorch/fallweightsresNet_3_12_2019%d.pth'%(count))

# %%
model_trained = train_model(model, criterion, optimizer, num_epochs=100)
# Out:
# Epoch 1/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# train loss: 0.6063, acc: 0.6945
# No file
# here
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.5589, acc: 0.7446
# Epoch 2/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# train loss: 0.5529, acc: 0.7455
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.5403, acc: 0.7662
# Epoch 3/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# train loss: 0.5184, acc: 0.7905
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.5000, acc: 0.8186
# Epoch 4/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# 40
# train loss: 0.5035, acc: 0.8093
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.5145, acc: 0.7888
# Epoch 5/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# train loss: 0.4971, acc: 0.8075
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.5566, acc: 0.7347
# Epoch 6/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# train loss: 0.5046, acc: 0.8010
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.4773, acc: 0.8285
# Epoch 7/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# train loss: 0.4821, acc: 0.8294
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.4888, acc: 0.8168
# Epoch 8/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# train loss: 0.4769, acc: 0.8382
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.4763, acc: 0.8348
# Epoch 9/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# train loss: 0.4759, acc: 0.8330
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.4779, acc: 0.8294
# Epoch 10/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# train loss: 0.4606, acc: 0.8532
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.4859, acc: 0.8150
# Epoch 11/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# train loss: 0.4678, acc: 0.8441
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.5163, acc: 0.7861
# Epoch 12/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# train loss: 0.4753, acc: 0.8299
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.4612, acc: 0.8457
# Epoch 13/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# train loss: 0.4513, acc: 0.8570
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.4600, acc: 0.8475
# Epoch 14/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# train loss: 0.4489, acc: 0.8630
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.4630, acc: 0.8394
# Epoch 15/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# train loss: 0.4479, acc: 0.8632
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.4494, acc: 0.8610
# Epoch 16/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# train loss: 0.4577, acc: 0.8508
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.4491, acc: 0.8646
# Epoch 17/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# train loss: 0.4482, acc: 0.8619
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.4502, acc: 0.8610
# Epoch 18/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# train loss: 0.4685, acc: 0.8369
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.4732, acc: 0.8258
# Epoch 19/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# 40
# train loss: 0.4709, acc: 0.8343
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.4509, acc: 0.8592
# Epoch 20/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# train loss: 0.4381, acc: 0.8751
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.4544, acc: 0.8556
# Epoch 21/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# train loss: 0.4335, acc: 0.8774
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.4475, acc: 0.8610
# Epoch 22/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# train loss: 0.4324, acc: 0.8790
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.4487, acc: 0.8619
# Epoch 23/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# train loss: 0.4298, acc: 0.8852
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.4526, acc: 0.8565
# Epoch 24/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# train loss: 0.4381, acc: 0.8723
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.4447, acc: 0.8637
# Epoch 25/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# train loss: 0.4327, acc: 0.8787
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.4428, acc: 0.8664
# Epoch 26/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# train loss: 0.4287, acc: 0.8810
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.4458, acc: 0.8628
# Epoch 27/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# 40
# train loss: 0.4260, acc: 0.8865
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.4495, acc: 0.8547
# Epoch 28/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# train loss: 0.4276, acc: 0.8870
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.5126, acc: 0.7888
# Epoch 29/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# train loss: 0.4556, acc: 0.8508
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.4464, acc: 0.8628
# Epoch 30/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# train loss: 0.4361, acc: 0.8730
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.4606, acc: 0.8457
# Epoch 31/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# train loss: 0.4350, acc: 0.8735
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.4432, acc: 0.8646
# Epoch 32/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# train loss: 0.4184, acc: 0.8968
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.4590, acc: 0.8475
# Epoch 33/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# train loss: 0.4199, acc: 0.8914
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.4455, acc: 0.8619
# Epoch 34/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# train loss: 0.4263, acc: 0.8854
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.4632, acc: 0.8502
# Epoch 35/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# train loss: 0.4266, acc: 0.8844
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.4406, acc: 0.8673
# Epoch 36/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# train loss: 0.4398, acc: 0.8710
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.4401, acc: 0.8709
# Epoch 37/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# train loss: 0.4174, acc: 0.8965
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.4404, acc: 0.8709
# Epoch 38/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# train loss: 0.4279, acc: 0.8839
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.4390, acc: 0.8664
# Epoch 39/100
# ----------
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-915-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID20200419005215_220-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-35-bbox.txt
# 40
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_171633(0)_frame-910-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-40-bbox.txt
# FileNotFoundError: ./dataset/alpha/Choke/train/NonChoking/VID_20200415_165905(0)_frame-30-bbox.txt
# train loss: 0.4149, acc: 0.8970
# FileNotFoundError: ./dataset/alpha/Choke/val/NonChoking/VID_20200415_171633(0)_frame-925-bbox.txt
# validation loss: 0.