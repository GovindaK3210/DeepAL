# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
from PIL import Image  , ImageDraw 
import torch
from torchvision import datasets, models, transforms
import torch.nn as nn
from torch.nn import functional as F
import torch.optim as optim
import os

# %%
torch.__version__
# Out:
# '1.5.0+cu101'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# %cd drive/My Drive/Resnet_Beta-Version
# !ls
# Out:
# /content/drive/My Drive/Resnet_Beta-Version
# 'alpha-Resnet(Raw+Face+Hand).ipynb'
# 'alpha-Resnet(Raw+Face).ipynb'
# 'alpha-Resnet(Raw+Hand).ipynb'
# 'alpha-Resnet(Raw).ipynb'
# 'Arrange Dataset.ipynb'
# 'beta-Resnet(Raw+Face+Hand).ipynb'
# 'beta-Resnet(Raw+Face+Hand+Pose)-Pose as Depth.ipynb'
# 'beta-Resnet(Raw+Face).ipynb'
# 'beta-Resnet(Raw+Hand).ipynb'
# 'beta-Resnet(Raw).ipynb'
# 'cropped_Resnet(Raw).ipynb'
#  dataset
#  dump
#  epoch_65.pth
#  extract_faceandhand_jorehgaye.ipynb
#  fallingDemo.ipynb
#  fallingDemo_modified_2.py
#  fallingDemo_modified.py
#  fallingDemo.py
#  loss
#  out.jpg
#  putTXT_rightplace.ipynb
# 'Testbeta-Resnet(Raw+Face+Hand).ipynb'
# 'Testbeta-Resnet(Raw+Face+Hand+Pose)-Pose as Depth.ipynb'
# 'testbeta-Resnet(Raw+Face).ipynb'
# 'Testbeta-Resnet(Raw+Hand).ipynb'
# 'Testbeta-Resnet(Raw).ipynb'
#  TestingModels_first.ipynb
#  TestingModels_second.ipynb
#  weights

# %%
normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                 std=[0.229, 0.224, 0.225])

data_transforms = {
    'train':
    transforms.Compose([
        transforms.Resize((224,224)),
        transforms.ToTensor(),
        #normalize
    ]),
    'validation':
    transforms.Compose([
        transforms.Resize((224,224)),
        transforms.ToTensor(),
        #normalize
    ]),
}

# %%
class MyImageFolder(datasets.ImageFolder):
    
    def __init__(self, root, transform=None):
        super(MyImageFolder,self).__init__(root)

        self.transform = transform

    def __getitem__(self, index):

        #imgs = self.imgs[index]
        #print(imgs)

        path, target = self.samples[index]
        #sample = self.loader(path)
        #print("Sample: ",sample)
        

        hm_transform = transforms.Compose([
                          transforms.Resize((224,224)),
                          transforms.ToTensor()

                                ])

        #print(path)
        #print(type(path))
        #all_images = []
        #all_labels = []
        #all_hm_face = []
        #all_hm_hand = []
        # target_acquired - 0: image path -- 1: label
        #for i in len(path):

        img_path = path
        #print("--i: %d , TA: %s"%(i,target_acquired))

        
        #img_path = target_acquired
        #label =  target_acquired[1]

        #print(img_path)

        image = Image.open(img_path)
        img_w , img_h = image.size

    
        filename = os.path.basename(img_path)
        ann_path = img_path.replace(filename, filename.split('.')[0] + '.txt')
        hm_face , hm_hand = self.get_heatmap(ann_path,img_w,img_h)  

        #image = np.dstack((image, hm_face))

        
        # Transforms
        if self.transform is not None:
            
            image = self.transform(image)
            hm_face = hm_transform(hm_face)
            hm_hand = hm_transform(hm_hand)

        image = torch.cat((image,hm_face,hm_hand))
        #if self.target_transform is not None:
        #    target = self.target_transform(target)
        
        
        # For Face
            #image = np.dstack((image, hm_face))

            #all_images.append(img_path)
            #all_labels.append(label)
            #all_hm_face.append(hm_face)
            #all_hm_hand.append(hm_hand)

        #return path, all_hm_face, all_hm_hand, target
        
        return image, target

    def get_heatmap(self,ann_path, img_w , img_h):
        
        hm_0 = Image.new('L', (img_w, img_h))
        hm_1 = Image.new('L', (img_w, img_h))
        
        try:

            with open(ann_path) as f:

                for line in f.readlines():

                    if line == '\n':
                        continue

                    line = line.split(' ')

                    cx = float(line[1])
                    cy = float(line[2])
                    w = float(line[3])
                    h = float(line[4])

                    xmin =  (cx - (w/2)) * img_w
                    ymin = (cy - (h/2)) * img_h
                    xmax = (cx + (w/2)) * img_w
                    ymax = (cy + (h/2)) * img_h

                    if line[0] == '0':
                        hmDraw = ImageDraw.Draw(hm_0)   
                    else:
                        hmDraw = ImageDraw.Draw(hm_1)   
                    
                    hmDraw.rectangle([xmin,ymin,xmax,ymax], fill ="#ffffff")
        except FileNotFoundError:
            print("FileNotFoundError: %s"%ann_path)
            #pass

        return hm_0, hm_1
"""
Test Code


path, target = self.samples[index]
sample = self.loader(path)
if self.transform is not None:
  sample = self.transform(sample)
if self.target_transform is not None:
  target = self.target_transform(target)
# this is where you load your resnet data
resnet_path = os.path.join(os.path.splitext(path)[0], '.pth')  # replace image extension with .pth
resnet = torch.load(resnet_path)  # load the stored features
return sample, resnet, target
"""
#dataset = MyImageFolder("falling_dataset/val/")
#re, labels = dataset[1:3]
#print(re)
#print(labels)
#re[2].save('pred_face.jpeg')
#re[3].save('pred_hand.jpeg')
# Out:
# "\nTest Code\n\n\npath, target = self.samples[index]\nsample = self.loader(path)\nif self.transform is not None:\n  sample = self.transform(sample)\nif self.target_transform is not None:\n  target = self.target_transform(target)\n# this is where you load your resnet data\nresnet_path = os.path.join(os.path.splitext(path)[0], '.pth')  # replace image extension with .pth\nresnet = torch.load(resnet_path)  # load the stored features\nreturn sample, resnet, target\n"

# %%
input_path = './dataset/alpha/Fall'

image_datasets = {
    'train': 
    MyImageFolder(input_path + '/train', data_transforms['train']),
    'validation': 
    MyImageFolder(input_path + '/val', data_transforms['validation'])
}

dataloaders = {
    'train':
    torch.utils.data.DataLoader(image_datasets['train'],
                                batch_size=64,
                                shuffle=True,
                                num_workers=2),  # for Kaggle
    'validation':
    torch.utils.data.DataLoader(image_datasets['validation'],
                                batch_size=1,
                                shuffle=False,
                                num_workers=2)  # for Kaggle
}

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cpu')

# %%
model = models.resnet50(pretrained=True).to(device)

model.cuda()
#print(model)

depth = 5


for param in model.parameters():
    param.requires_grad = False   


#------------ Modify First Layer
model.conv1 = nn.Conv2d(depth, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False).to(device)
model.conv1.requires_grad = True

#------------ Modify Last Layer
model.fc = nn.Sequential(
               nn.Linear(2048, 128),
               nn.ReLU(inplace=True),
               nn.Linear(128, 2),
               nn.Sigmoid()).to(device)

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.fc.parameters(),lr=0.001)

# %%
def train_model(model, criterion, optimizer, num_epochs=3):
    new_write = True
    for epoch in range(num_epochs):
        
        #f = open('loss/alpha/raw-face-hand.txt','a+')
        
        print('Epoch {}/{}'.format(epoch+1, num_epochs))
        print('-' * 10)
        #f.write('Epoch {}/{}\n'.format(epoch+1, num_epochs))
        

        for phase in ['train','validation']:
            if phase == 'train':
                model.train()
            else:
                model.eval()

            running_loss = 0.0
            running_corrects = 0
            count = 0
            
            with torch.set_grad_enabled(phase == 'train'):
              for inputs, labels in dataloaders[phase]:
                  inputs = inputs.to(device)
                  labels = labels.to(device)

                  outputs = model(inputs)
                  loss = criterion(outputs, labels)

                  if phase == 'train':
                      
                      optimizer.zero_grad()
                      loss.backward()
                      optimizer.step()

                  _, preds = torch.max(outputs, 1)
                  running_loss += loss.item() * inputs.size(0)
                  running_corrects += torch.sum(preds == labels.data)

                  count = count+1                
                  if (count%40==0):
                    print (count)
             

            epoch_loss = running_loss / len(image_datasets[phase])
            epoch_acc = running_corrects.double() / len(image_datasets[phase])

            print('{} loss: {:.4f}, acc: {:.4f}'.format(phase,epoch_loss,epoch_acc))
            if (os.path.isfile('loss/alpha/Fall/raw_face_hand.txt')):
              new_write=False  
            else :
              print ("No file")
            f = open('loss/alpha/Fall/raw_face_hand.txt','a+')
            if  (new_write == True ):
              print ("here")
              f.write('{} loss: {:.4f}, acc: {:.4f}'.format(phase,epoch_loss,epoch_acc))
            else :
              f.write ('\n')
              f.write('{} loss: {:.4f}, acc: {:.4f}'.format(phase,epoch_loss,epoch_acc))
            
        torch.save(model, 'weights/alpha/Fall/raw-face-hand/epoch_%d.pth'%(epoch))
        f.close()


    return model

# %%
# !pwd
# Out:
# /content/drive/My Drive/Resnet_Beta-Version

# %%
# !pwd

model_trained = train_model(model, criterion, optimizer, num_epochs=100)
# Out:
# Streaming output truncated to the last 5000 lines.
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162918191.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/Falling/17325.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162629119.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162629419.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162918177.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162918195.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162629357.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/Falling/17315.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162629522.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID2019120216262945.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID2019120216262966.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/Falling/17305.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID2019120216262943.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/Falling/17304.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162629526.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162629136.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162629124.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID2019120216262989.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162629541.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162629553.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162629131.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID2019120216262925.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162629513.txt
# train loss: 0.3934, acc: 0.9195
# FileNotFoundError: ./dataset/alpha/Fall/val/Falling/12119.txt
# 40
# FileNotFoundError: ./dataset/alpha/Fall/val/Falling/17308.txt
# FileNotFoundError: ./dataset/alpha/Fall/val/Falling/17306.txt
# FileNotFoundError: ./dataset/alpha/Fall/val/Falling/17311.txt
# 80
# 120
# 160
# 200
# 240
# FileNotFoundError: ./dataset/alpha/Fall/val/Falling/IMG_5771_Frame144.txt
# 280
# FileNotFoundError: ./dataset/alpha/Fall/val/Falling/IMG_5790_Frame80.txt
# 320
# FileNotFoundError: ./dataset/alpha/Fall/val/Falling/VID20191202161842170.txt
# 360
# 400
# 440
# 480
# 520
# 560
# 600
# 640
# 680
# 720
# 760
# 800
# 840
# FileNotFoundError: ./dataset/alpha/Fall/val/NonFalling/VID20191202162629121.txt
# FileNotFoundError: ./dataset/alpha/Fall/val/NonFalling/VID20191202162629117.txt
# FileNotFoundError: ./dataset/alpha/Fall/val/NonFalling/VID20191202162629129.txt
# FileNotFoundError: ./dataset/alpha/Fall/val/NonFalling/VID20191202162629127.txt
# FileNotFoundError: ./dataset/alpha/Fall/val/NonFalling/VID20191202162629133.txt
# FileNotFoundError: ./dataset/alpha/Fall/val/NonFalling/VID20191202162629155.txt
# FileNotFoundError: ./dataset/alpha/Fall/val/NonFalling/VID20191202162629174.txt
# 880
# FileNotFoundError: ./dataset/alpha/Fall/val/NonFalling/VID20191202162629351.txt
# FileNotFoundError: ./dataset/alpha/Fall/val/NonFalling/VID20191202162629356.txt
# FileNotFoundError: ./dataset/alpha/Fall/val/NonFalling/VID20191202162629397.txt
# FileNotFoundError: ./dataset/alpha/Fall/val/NonFalling/VID20191202162629411.txt
# FileNotFoundError: ./dataset/alpha/Fall/val/NonFalling/VID20191202162629415.txt
# FileNotFoundError: ./dataset/alpha/Fall/val/NonFalling/VID20191202162629416.txt
# FileNotFoundError: ./dataset/alpha/Fall/val/NonFalling/VID20191202162629421.txt
# FileNotFoundError: ./dataset/alpha/Fall/val/NonFalling/VID20191202162629418.txt
# FileNotFoundError: ./dataset/alpha/Fall/val/NonFalling/VID20191202162629424.txt
# FileNotFoundError: ./dataset/alpha/Fall/val/NonFalling/VID20191202162629514.txt
# FileNotFoundError: ./dataset/alpha/Fall/val/NonFalling/VID20191202162629512.txt
# FileNotFoundError: ./dataset/alpha/Fall/val/NonFalling/VID20191202162629518.txt
# FileNotFoundError: ./dataset/alpha/Fall/val/NonFalling/VID20191202162629517.txt
# FileNotFoundError: ./dataset/alpha/Fall/val/NonFalling/VID20191202162629521.txt
# FileNotFoundError: ./dataset/alpha/Fall/val/NonFalling/VID20191202162629524.txt
# 920
# FileNotFoundError: ./dataset/alpha/Fall/val/NonFalling/VID20191202162629529.txt
# FileNotFoundError: ./dataset/alpha/Fall/val/NonFalling/VID20191202162629537.txt
# FileNotFoundError: ./dataset/alpha/Fall/val/NonFalling/VID20191202162629547.txt
# FileNotFoundError: ./dataset/alpha/Fall/val/NonFalling/VID2019120216262995.txt
# FileNotFoundError: ./dataset/alpha/Fall/val/NonFalling/VID2019120216262996.txt
# FileNotFoundError: ./dataset/alpha/Fall/val/NonFalling/VID2019120216262997.txt
# FileNotFoundError: ./dataset/alpha/Fall/val/NonFalling/VID20191202162918178.txt
# FileNotFoundError: ./dataset/alpha/Fall/val/NonFalling/VID20191202162918171.txt
# FileNotFoundError: ./dataset/alpha/Fall/val/NonFalling/VID201912021629182.txt
# FileNotFoundError: ./dataset/alpha/Fall/val/NonFalling/VID201912021629184.txt
# FileNotFoundError: ./dataset/alpha/Fall/val/NonFalling/VID201912021629186.txt
# 960
# FileNotFoundError: ./dataset/alpha/Fall/val/NonFalling/VID201912021629188.txt
# 1000
# 1040
# 1080
# validation loss: 0.4807, acc: 0.8276
# Epoch 79/100
# ----------
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID201912021626295.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162629543.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID2019120216195292.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID201912021626298.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162629538.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID2019120216262966.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/Falling/VID20191202161842169.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/Falling/17314.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162918189.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162629544.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162629548.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162629404.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162629120.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID201912021626294.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162629349.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162629137.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162629122.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/Falling/VID20191202161842175.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/Falling/IMG_5790_Frame84.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162629359.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162918191.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162629412.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID201912021626293.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/Falling/17305.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162918186.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID2019120216262910.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/Falling/17304.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162629423.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/Falling/VID20191202161842174.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162629401.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162629157.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID2019120216262998.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162918172.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/Falling/17317.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162629519.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID2019120216262999.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162629545.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162629549.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID2019120216262993.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162918182.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/Falling/17310.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162629358.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162629534.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162629177.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162629398.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/Falling/VID20191202161842168.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162629131.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID2019120216262945.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID2019120216262968.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID2019120216262992.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162629511.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/Falling/17324.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID2019120216262986.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/Falling/17303.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/Falling/17316.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162629119.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162629540.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162629426.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID201912021626299.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162629128.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID2019120216262942.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162629170.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162629531.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/Falling/17315.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162629507.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162629510.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162629130.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162629551.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162629175.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID2019120216262925.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/Falling/VID20191202161020147.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162629526.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID2019120216262967.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162629124.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162629555.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/1938.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162629118.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID2019120216262991.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162629116.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID2019120216262911.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162629546.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162629405.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/Falling/17307.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162629173.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162629115.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162629171.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID201912021626297.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID2019120216262944.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162629123.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162629553.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162629506.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162629425.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/Falling/17309.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162629350.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID2019120216262943.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162629136.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162629562.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162629515.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162918195.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162629513.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162629410.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162629172.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162629541.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162629352.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/Falling/IMG_5790_Frame76.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162629407.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162629403.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162629539.txt
# 40
# FileNotFoundError: ./dataset/alpha/Fall/train/Falling/17313.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162629125.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162629355.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162629520.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID2019120216262987.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID2019120216262969.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID2019120216262994.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/Falling/17322.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162629135.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID2019120216262989.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162629532.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/Falling/VID20191202161842173.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162629508.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162629353.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/Falling/VID20191202161842172.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/Falling/17319.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162629420.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162629535.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162629419.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/Falling/17312.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/Falling/17325.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162629516.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162629134.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162629156.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162629132.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/Falling/VID20191202161842171.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID20191202162629402.txt
# FileNotFoundError: ./dataset/alpha/Fall/train/NonFalling/VID2019120216
# FileNotFoundError: ./dataset/alpha/Fall/val/NonFalling/VID201912021629186.txt
# 960
# FileNotFoundError: ./dataset/alpha/Fall/val/NonFalling/VID201912021629188.txt
# 1000
# 1040
# 1080
# validation loss: 0.3970, acc: 0.9125

# %%
#torch.save(model_trained.state_dict(), 'weights/pytorch/weightsE3.h5')
epoch =100
torch.save(model_trained, 'weights/alpha/raw-face-hand/epoch_%d.pth'%(epoch))

# %%
# model = models.resnet50(pretrained=False).to(device)
# model.fc = nn.Sequential(
#                nn.Linear(2048, 128),
#                nn.ReLU(inplace=True),
#                nn.Linear(128, 2)).to(device)
model = (torch.load('weights/pytorch/fallweightsresNet_3_12_201990.pth'))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-506-946e2761658d> in <module>()
# ----> 1 model = (torch.load('weights/pytorch/fallweightsresNet_3_12_201990.pth'))
#
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py in load(f, map_location, pickle_module, **pickle_load_args)
#     417             (sys.version_info[0] == 2 and isinstance(f, unicode)):
#     418         new_fd = True
# --> 419         f = open(f, 'rb')
#     420     elif (sys.version_info[0] == 3 and isinstance(f, pathlib.Path)):
#     421         new_fd = True
#
# FileNotFoundError: [Errno 2] No such file or directory: 'weights/pytorch/fallweightsresNet_3_12_201990.pth'

# %%
# !ls
# Out:
# darknet		      examples	      opt.py		train_sppe
# data		      fallmodel.pth   output		video_ann.py
# datalabeler_101.py    fi_data	      PoseFlow		video_demo.py
# datalabeler_111.py    fn.py	      pPose_nms.py	webcam_demo.py
# datalabeler_249.py    img.png	      __pycache__	weights
# dataloader.py	      LICENSE	      README.md		yolo
# dataloader_webcam.py  matching.py     requirements.txt
# demo.py		      models	      resnetWeights
# doc		      online_demo.py  SPPE

# %%
import glob
import random
pathFalling = './fi_data/train/Falling/'
pathNonFalling = './fi_data/train/NonFalling/'
accurateFalling = 0
accurateNonFalling = 0

list1= [f for f in glob.glob(pathFalling + "*.jpg", recursive=True)]
list2= [f for f in glob.glob(pathNonFalling + "*.jpg", recursive=True)]
validation_img_pathsFalling=random.sample(list1,100)
validation_img_pathsNonFalling = random.sample(list2,100)
img_listFalling = [Image.open('./' + img_path) for img_path in validation_img_pathsFalling]
img_listNonFalling = [Image.open('./' + img_path) for img_path in validation_img_pathsNonFalling]
print (len(img_listFalling))
print (len(img_listNonFalling))
# Out:
# 100
# 100

# %%
validation_batchFalling = torch.stack([data_transforms['validation'](img).to(device)
                                for img in img_listFalling])
validation_batchNonFalling = torch.stack([data_transforms['validation'](img).to(device)
                                for img in img_listNonFalling])

# %%
pred_logits_tensorFalling = model(validation_batchFalling)
pred_logits_tensorFalling
pred_logits_tensorNonFalling = model(validation_batchNonFalling)
pred_logits_tensorNonFalling
# Out:
# tensor([[-1.5283e+00,  9.0661e-01],
#         [-2.2185e+00,  2.1231e+00],
#         [-2.7703e+00,  3.2524e+00],
#         [-2.4615e+00,  2.0275e+00],
#         [-1.1705e+00,  9.6872e-01],
#         [-4.7061e-01,  8.8000e-01],
#         [-1.1260e+00,  6.5979e-01],
#         [-3.8996e+00,  4.1767e+00],
#         [-5.8298e-01,  2.0960e-01],
#         [-7.5061e-01,  5.5574e-01],
#         [-2.2707e+00,  2.1771e+00],
#         [-1.5751e+00,  1.3934e+00],
#         [-9.6311e-01,  3.2051e-01],
#         [-2.7319e+00,  2.2038e+00],
#         [-9.1111e-02, -3.2099e-03],
#         [ 7.4642e-02, -3.1217e-01],
#         [-1.6257e+00,  1.6039e+00],
#         [-3.4561e+00,  3.4454e+00],
#         [-3.1866e+00,  2.6508e+00],
#         [-6.3874e-01,  3.6337e-01],
#         [-1.6754e+00,  1.5005e+00],
#         [-2.6561e+00,  2.5272e+00],
#         [-4.2902e+00,  3.4453e+00],
#         [-5.9180e+00,  5.5812e+00],
#         [-1.1807e+00,  3.4439e-01],
#         [ 5.9854e-01, -1.1552e+00],
#         [-1.0886e+00,  1.4284e+00],
#         [-1.3321e+00,  6.7604e-01],
#         [-3.9996e+00,  4.3648e+00],
#         [-1.4083e+00,  6.0351e-01],
#         [-1.2264e+00,  1.0991e+00],
#         [-1.1462e+00,  1.5402e+00],
#         [-1.8286e+00,  1.3528e+00],
#         [-2.3552e+00,  1.6984e+00],
#         [-2.1288e+00,  1.1955e+00],
#         [-1.5181e+00,  1.5338e+00],
#         [-1.5709e+00,  1.1303e+00],
#         [-4.8410e-01,  6.5407e-01],
#         [-2.3557e+00,  2.3572e+00],
#         [-3.0127e+00,  2.5141e+00],
#         [-8.9294e-01,  1.4338e+00],
#         [-1.8556e+00,  1.8566e+00],
#         [-5.4278e+00,  4.6284e+00],
#         [-4.1913e+00,  3.6048e+00],
#         [-2.5902e+00,  3.2030e+00],
#         [-4.3144e-01,  1.1479e-02],
#         [-1.3009e+00,  8.0105e-01],
#         [-2.2613e+00,  2.1988e+00],
#         [-4.1856e+00,  4.6559e+00],
#         [-1.3123e+00,  1.2976e+00],
#         [-7.1605e-01,  7.7414e-01],
#         [-9.3769e-01,  5.5449e-01],
#         [-2.7523e-01,  4.5086e-01],
#         [-5.9862e-01,  6.5938e-01],
#         [-5.5110e-01,  7.1522e-01],
#         [-1.4533e+00,  1.3194e+00],
#         [-3.6628e-01,  5.3456e-01],
#         [-1.5910e-02, -2.1306e-01],
#         [ 9.9029e-01, -1.1457e+00],
#         [-2.3818e+00,  1.2950e+00],
#         [-1.8751e-01, -2.2348e-01],
#         [-7.1883e-01,  6.9083e-01],
#         [-1.5626e+00,  7.8728e-01],
#         [-3.2653e+00,  2.8928e+00],
#         [-1.0470e+00,  1.4566e+00],
#         [-2.4478e+00,  2.1214e+00],
#         [-1.9986e+00,  1.6184e+00],
#         [-2.6359e+00,  3.0996e+00],
#         [-1.3386e+00,  1.2090e+00],
#         [-5.6010e+00,  5.4263e+00],
#         [ 1.9908e-01, -6.4550e-01],
#         [-1.0548e+00,  7.7043e-01],
#         [-1.7256e+00,  1.6099e+00],
#         [-1.6930e+00,  1.5251e+00],
#         [-8.9278e-01,  1.0659e+00],
#         [-1.5189e+00,  2.0518e+00],
#         [-1.5340e+00,  1.3930e+00],
#         [-1.9736e+00,  1.9908e+00],
#         [-2.1943e+00,  1.9718e+00],
#         [-3.6745e+00,  3.4456e+00],
#         [-1.4028e+00,  1.2741e+00],
#         [-1.0761e+00,  2.7409e-01],
#         [-2.2563e+00,  1.9396e+00],
#         [-4.5813e-01,  2.2948e-01],
#         [-1.7392e-01,  1.7755e-01],
#         [-4.5903e-01,  1.5764e-01],
#         [ 1.5427e-01,  6.7129e-02],
#         [-9.6840e-01,  7.4926e-01],
#         [-1.7579e+00,  6.5922e-01],
#         [-9.5639e-01,  2.9800e-01],
#         [-9.1485e-01,  1.3002e-02],
#         [-2.0708e+00,  1.6325e+00],
#         [-8.4738e-01,  6.4695e-01],
#         [-1.6241e+00,  1.3681e+00],
#         [-1.6971e+00,  9.6811e-01],
#         [-9.3705e-01,  8.7947e-02],
#         [-1.5653e+00,  1.3531e+00],
#         [-5.8697e-01,  2.4690e-01],
#         [-2.9740e+00,  3.8499e+00],
#         [-2.1410e-01, -5.4011e-01]], device='cuda:0', grad_fn=<AddmmBackward>)

# %%
pred_probsFalling = F.softmax(pred_logits_tensorFalling, dim=1).cpu().data.numpy()
print (pred_probsFalling)
pred_probsNonFalling = F.softmax(pred_logits_tensorNonFalling, dim=1).cpu().data.numpy()
print (pred_probsNonFalling)
# Out:
# [[0.44844374 0.5515562 ]
#  [0.12725133 0.8727487 ]
#  [0.09804448 0.9019555 ]
#  [0.00425655 0.99574345]
#  [0.8194356  0.18056442]
#  [0.24643923 0.7535607 ]
#  [0.13835269 0.8616473 ]
#  [0.1574074  0.84259254]
#  [0.8485861  0.1514139 ]
#  [0.32346088 0.6765391 ]
#  [0.41357878 0.58642125]
#  [0.15117285 0.8488271 ]
#  [0.6003375  0.39966255]
#  [0.02290936 0.9770906 ]
#  [0.10023551 0.89976454]
#  [0.29872367 0.70127636]
#  [0.04371396 0.956286  ]
#  [0.61934406 0.38065597]
#  [0.30597326 0.6940267 ]
#  [0.16753031 0.8324697 ]
#  [0.66433    0.33567002]
#  [0.84191    0.15808995]
#  [0.6628018  0.33719823]
#  [0.4977156  0.50228435]
#  [0.87176895 0.12823105]
#  [0.02149463 0.9785054 ]
#  [0.48655316 0.5134468 ]
#  [0.44041517 0.55958486]
#  [0.1114507  0.88854927]
#  [0.5616096  0.4383904 ]
#  [0.570884   0.42911607]
#  [0.32838956 0.6716105 ]
#  [0.42478982 0.5752102 ]
#  [0.5371839  0.46281612]
#  [0.02694354 0.9730565 ]
#  [0.61242115 0.3875789 ]
#  [0.21000993 0.7899901 ]
#  [0.32981074 0.6701893 ]
#  [0.23768397 0.76231605]
#  [0.846486   0.15351407]
#  [0.68354267 0.3164573 ]
#  [0.4176136  0.58238643]
#  [0.06766645 0.9323336 ]
#  [0.69376177 0.30623817]
#  [0.9771763  0.02282374]
#  [0.07331121 0.92668885]
#  [0.11293977 0.8870603 ]
#  [0.37429568 0.6257043 ]
#  [0.7112252  0.2887748 ]
#  [0.5165122  0.4834878 ]
#  [0.47287163 0.52712834]
#  [0.96339136 0.03660858]
#  [0.7991366  0.2008634 ]
#  [0.49161175 0.5083883 ]
#  [0.8278209  0.17217906]
#  [0.24142899 0.75857097]
    accurateFalling= accurateFalling +1 
i=0
accurateNonFalling=0
for i in range(len(pred_probsNonFalling)):
  if (pred_probsNonFalling[i][1]> 0.5):
    accurateNonFalling= accurateNonFalling +1

# %%
overallAccuracy = (accurateNonFalling+accurateFalling)/(len(img_listFalling)+len(img_listNonFalling))

# %%
print (accurateFalling)
print (accurateNonFalling)
# Out:
# 41
# 92

# %%
print (overallAccuracy)
# Out:
# 0.665

# %%
ig, axs = plt.subplots(1, len(img_listFalling), figsize=(150, 150))
for i, img in enumerate(img_listFalling):
    ax = axs[i]
    ax.axis('off')
    ax.set_title("{:.0f}%Falling , {:.0f}% Non-Falling".format(100*pred_probsFalling[i,0],
                                                          100*pred_probsFalling[i,1]))
    ax.imshow(img)

# %%
ig, axs = plt.subplots(1, len(img_listNonFalling), figsize=(150, 150))
for i, img in enumerate(img_listNonFalling):
    ax = axs[i]
    ax.axis('off')
    ax.set_title("{:.0f}%Falling , {:.0f}% Non-Falling".format(100*pred_probsNonFalling[i,0],
                                                          100*pred_probsNonFalling[i,1]))
    ax.imshow(img)

# %%
epoch = 37
device = 'cpu'
model = torch.load('weights/raw-face-hand/fallweightsresNetEpoch_%d.pth'%(epoch)).to(device)
model.eval()
# Out:
# ResNet(
#   (conv1): Conv2d(5, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Sequential(
#     (0): Linear(in_features=2048, out_features=128, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Linear(in_features=128, out_features=2, bias=True)
#   )
# )

# %%
predictions = []
target = []

iteration = 0

for inputs , labels in dataloaders['validation']:

    if iteration == 150:
      break
    iteration += 1
    inputs = inputs.to(device)
    labels = labels.to(device)

    pred_logits_tensorFalling = model(inputs)
    predictions.append(pred_logits_tensorFalling)
    target.append(labels)

    print("Done")
# Out:
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-7-4828a7b4b2c1> in <module>()
#      12     labels = labels.to(device)
#      13
# ---> 14     pred_logits_tensorFalling = model(inputs)
#      15     predictions.append(pred_logits_tensorFalling)
#      16     target.append(labels)
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# /usr/local/lib/python3.6/dist-packages/torchvision/models/resnet.py in forward(self, x)
#     201         x = self.layer1(x)
#     202         x = self.layer2(x)
# --> 203         x = self.layer3(x)
#     204         x = self.layer4(x)
#     205
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/container.py in forward(self, input)
#      90     def forward(self, input):
#      91         for module in self._modules.values():
# ---> 92             input = module(input)
#      93         return input
#      94
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# /usr/local/lib/python3.6/dist-packages/torchvision/models/resnet.py in forward(self, x)
#     101
#     102         out = self.conv2(out)
# --> 103         out = self.bn2(out)
#     104         out = self.relu(out)
#     105
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/batchnorm.py in forward(self, input)
#      79             input, self.running_mean, self.running_var, self.weight, self.bias,
#      80             self.training or not self.track_running_stats,
# ---> 81             exponential_average_factor, self.eps)
#      82
#      83     def extra_repr(self):
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py in batch_norm(input, running_mean, running_var, weight, bias, training, momentum, eps)
#    1668     return torch.batch_norm(
#    1669         input, weight, bias, running_mean, running_var,
# -> 1670         training, momentum, eps, torch.backends.cudnn.enabled
#    1671     )
#    1672
#
# /usr/local/lib/python3.6/dist-packages/torch/backends/__init__.py in __get__(self, obj, objtype)
#      30
#      31     def __get__(self, obj, objtype):
# ---> 32         return self.getter()
#      33
#      34     def __set__(self, obj, val):
#
# /usr/local/lib/python3.6/dist-packages/torch/utils/data/_utils/signal_handling.py in handler(signum, frame)
#      64         # This following call uses `waitid` with WNOHANG from C side. Therefore,
#      65         # Python can still get and update the process status successfully.
# ---> 66         _error_if_any_worker_fails()
#      67         if previous_handler is not None:
#      68             previous_handler(signum, frame)
#
# RuntimeError: DataLoader worker (pid 1369) is killed by signal: Killed.

# %%
out = []

for pred in predictions:

    out.append( torch.argmax(pred).item()) 

acc = 0
for i,tar in enumerate(target):
    if tar.item() == out[i]:
      acc += 1

print("acc", acc)
print("total",len(out))
print(acc/len(out))
# Out:
# acc 89
# total 108
# 0.8240740740740741
